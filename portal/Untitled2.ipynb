# %%
import urllib

params = 'DRIVER={ODBC Driver 13 for SQL Server};' \
         'SERVER=localhost;' \
         'PORT=1433;' \
         'DATABASE=DbAsftPortal;' \
         'UID=sa;' \
         'PWD=aSj#14776$10036%mM&;'
            
params = urllib.parse.quote_plus(params)

from sqlalchemy import create_engine

db = create_engine('mssql+pyodbc:///?odbc_connect=%s' % params)

import pandas as pd

sql = '''
SELECT TABLE_NAME
FROM INFORMATION_SCHEMA.TABLES
WHERE TABLE_TYPE = 'BASE TABLE' AND TABLE_CATALOG='DbAsftPortal'
'''

pd.read_sql_query(sql, db)
# Out:
#                                   TABLE_NAME
# 0                             knox_authtoken
# 1                           tbl_library_book
# 2                    tbl_library_book_author
# 3                 tbl_library_book_publisher
# 4                      tbl_library_book_type
# 5                    tbl_library_loaned_book
# 6                        tbl_meeting_request
# 7                    tbl_resturaunt_day_meal
# 8              tbl_resturaunt_guest_day_meal
# 9                        tbl_resturaunt_meal
# 10    tbl_resturaunt_guest_day_meal_junction
# 11          tbl_resturaunt_employee_day_meal
# 12                         django_migrations
# 13                       django_content_type
# 14                            django_session
# 15                           auth_permission
# 16                         tbl_survey_answer
# 17                                auth_group
# 18                       tbl_survey_question
# 19                    auth_group_permissions
# ...

# %%
from datetime import datetime, date, time
from meeting_request.models import Meeting_Room, Meeting_Request
from baseInfo.models import Department, Employee

d = date.today()
# d = '2021-05-17'
# print('today = ', d)
# date = datetime.strptime(d, '%Y-%m-%d').date()
dep = Department.objects.get(pk=1)
emp = Employee.objects.get(pk=1)
room = Meeting_Room.objects.get(pk=1)
start_hour=time(8,0,0,0)
end_hour=time(10,0,0,0)

# print(Meeting_Request.objects.all())

# if(result.exists() and len(result) > 0):
#     result = result.filter(date=date)
#     print('a= ', result)
# print('result = ', result if result.exists() else None)
Meeting_Request.objects.create(date=d, start_hour=startHour, end_hour=startHour, requester=emp, meeting_room=room, department=dep)
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# D:\asft\portal-backend\env\lib\site-packages\django\db\backends\base\base.py in temporary_connection(self)
#     603         try:
# --> 604             with self.cursor() as cursor:
#     605                 yield cursor
#
# D:\asft\portal-backend\env\lib\site-packages\django\utils\asyncio.py in inner(*args, **kwargs)
#      23                     if event_loop.is_running():
# ---> 24                         raise SynchronousOnlyOperation(message)
#      25             # Pass onwards.
#
# SynchronousOnlyOperation: You cannot call this from an async context - use a thread or sync_to_async.
#
# During handling of the above exception, another exception occurred:
#
# SynchronousOnlyOperation                  Traceback (most recent call last)
# <ipython-input-44-ab7ba9051302> in <module>
#       7 # print('today = ', d)
# ...
