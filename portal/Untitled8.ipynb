# %%
import urllib

params = 'DRIVER={ODBC Driver 13 for SQL Server};' \
         'SERVER=localhost;' \
         'PORT=1433;' \
         'DATABASE=DbAsftPortal;' \
         'UID=sa;' \
         'PWD=aSj#14776$10036%mM&;'
            
params = urllib.parse.quote_plus(params)

from sqlalchemy import create_engine

db = create_engine('mssql+pyodbc:///?odbc_connect=%s' % params)

import pandas as pd

sql = '''
SELECT TABLE_NAME
FROM INFORMATION_SCHEMA.TABLES
WHERE TABLE_TYPE = 'BASE TABLE' AND TABLE_CATALOG='DbAsftPortal'
'''

pd.read_sql_query(sql, db)
# Out:
#                                 TABLE_NAME
# 0                           knox_authtoken
# 1                         tbl_library_book
# 2                  tbl_library_book_author
# 3               tbl_library_book_publisher
# 4                    tbl_library_book_type
# 5                  tbl_library_loaned_book
# 6                   tbl_meeting_cater_type
# 7                    tbl_meeting_equipment
# 8                      tbl_meeting_request
# 9                         tbl_meeting_room
# 10                   tbl_meeting_room_type
# 11              tbl_meeting_room_equipment
# 12          tbl_meeting_request_cater_type
# 13                 tbl_resturaunt_day_meal
# 14                       django_migrations
# 15           tbl_resturaunt_guest_day_meal
# 16                     django_content_type
# 17                     tbl_resturaunt_meal
# 18                         auth_permission
# 19  tbl_resturaunt_guest_day_meal_junction
# 20                              auth_group
# 21        tbl_resturaunt_employee_day_meal
# 22                  auth_group_permissions
# 23                               auth_user
# 24                        auth_user_groups
# 25              auth_user_user_permissions
# 26                          django_session
# 27                       tbl_survey_answer
# 28                     tbl_survey_question
# 29                       tbl_survey_survey
# 30                        django_admin_log
# 31                  tbl_survey_user_answer
# 32                   tbl_survey_department
# 33                        tbl_base_company
# 34                     tbl_base_department
# 35                          tbl_doctorType
# 36                    tbl_base_jobPosition
# 37                          tbl_surveyType
# 38                        tbl_base_project
# 39                   tbl_base_notification
# 40                       tbl_base_employee
# 41           tbl_meeting_request_equipment
# 42                    tbl_doc_appointments
# 43                             tbl_doctors
# 44               tbl_doc_schedule_weekdays
# 45                   tbl_doc_schedule_days
# 46                  tbl_doc_patients_files
# 47                        tbl_doc_patients
# 48               tbl_doc_appointment_times

# %%
import os
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

from datetime import datetime, date
from resturaunt.models import Resturaunt_Meal, Resturaunt_Day_Meal, Resturaunt_Employee_Day_Meal

currentdate = date.today()
y = currentdate.year
m = currentdate.month
d = currentdate.day
startdate = ""
enddate = ""
if(m == 1):
    startdate += str(y-1) if (d < 21) else str(y)  
    startdate += "-12" if (d < 21) else "-01" 
    startdate += "-22" if (d < 21) else "-21"
    
    enddate += str(y)  
    enddate += "-01" if (d < 21) else "-02" 
    enddate += "-20" if (d < 21) else "-19"
elif(m == 2):
    startdate += str(y) 
    startdate += "-01" if (d < 20) else "-02" 
    startdate += "-21" if (d < 20) else "-20"
        
    enddate += str(y)  
    enddate += "-02" if (d < 20) else "-03" 
    enddate += "-19" if (d < 20) else "-20"
elif(m == 3):
    startdate += str(y) 
    startdate += "-02" if (d < 21) else "-03" 
    startdate += "-20" if (d < 21) else "-21"
        
    enddate += str(y)  
    enddate += "-03" if (d < 21) else "-04" 
    enddate += "-20" if (d < 21) else "-20"
elif(m == 4):
    startdate += str(y) 
    startdate += "-03" if (d < 21) else "-04" 
    startdate += "-21" if (d < 21) else "-21"
        
    enddate += str(y)  
    enddate += "-04" if (d < 21) else "-05" 
    enddate += "-20" if (d < 21) else "-21"
elif(m == 5):
    startdate += str(y) 
    startdate += "-04" if (d < 22) else "-05" 
    startdate += "-21" if (d < 22) else "-22" 
        
    enddate += str(y)  
    enddate += "-05" if (d < 22) else "-06" 
    enddate += "-21" if (d < 22) else "-21"
elif(m == 6):
    startdate += str(y) 
    startdate += "-05" if (d < 22) else "-06" 
    startdate += "-22" if (d < 22) else "-22" 
        
    enddate += str(y)  
    enddate += "-06" if (d < 22) else "-06" 
    enddate += "-21" if (d < 22) else "-22"
elif(m == 7):
    startdate += str(y) 
    startdate += "-06" if (d < 23) else "-07" 
    startdate += "-23" if (d < 23) else "-23" 
        
    enddate += str(y)  
    enddate += "-07" if (d < 23) else "-08" 
    enddate += "-22" if (d < 23) else "-22"
elif(m == 8):
    startdate += str(y) 
    startdate += "-07" if (d < 23) else "-08" 
    startdate += "-23" if (d < 23) else "-23" 
        
    enddate += str(y)  
    enddate += "-08" if (d < 23) else "-09" 
    enddate += "-22" if (d < 23) else "-22"
elif(m == 9):
    startdate = str(y) 
    startdate += "-08" if (d < 23) else "-09" 
    startdate += "-23" if (d < 23) else "-23" 
        
    enddate += str(y)  
    enddate += "-09" if (d < 23) else "-10" 
    enddate += "-22" if (d < 23) else "-22"
elif(m == 10):
    startdate += str(y) 
    startdate += "-09" if (d < 23) else "-10" 
    startdate += "-23" if (d < 23) else "-23" 
        
    enddate += str(y)  
    enddate += "-10" if (d < 23) else "-11" 
    enddate += "-22" if (d < 23) else "-21"
elif(m == 11):
    startdate += str(y) 
    startdate += "-10" if (d < 22) else "-11" 
    startdate += "-23" if (d < 22) else "-22" 
        
    enddate += str(y)  
    enddate += "-11" if (d < 22) else "-12" 
    enddate += "-21" if (d < 22) else "-21"
elif(m == 12):
    startdate += str(y) 
    startdate += "-11" if (d < 22) else "-12" 
    startdate += "-22" if (d < 22) else "-22" 
        
    enddate += str(y) if (d < 22) else str(y+1)
    enddate += "-12" if (d < 22) else "-01" 
    enddate += "-21" if (d < 22) else "-20"
    

beginDate = datetime.strptime(startdate, '%Y-%m-%d').date()  
finishDate = datetime.strptime(enddate, '%Y-%m-%d').date()   
print(mealDate)
print('=============================================')

employee_id = 1585
results = (Resturaunt_Employee_Day_Meal.objects.filter(employee=employee_id, 
    resturaunt_day_meal__date__gte=startdate, resturaunt_day_meal__date__lte=enddate).order_by('-resturaunt_day_meal__date')[:31].values('resturaunt_day_meal__date', 'resturaunt_day_meal__resturaunt_meal__name')[::-1])
for item in results:
    print(item)
    print('-----------------------------------------------')
# Out:
# 2021-07-23
# =============================================
# {'resturaunt_day_meal__date': datetime.date(2021, 7, 31), 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه کباب زعفرانی'}
# -----------------------------------------------
# {'resturaunt_day_meal__date': datetime.date(2021, 8, 1), 'resturaunt_day_meal__resturaunt_meal__name': 'ته چین مرغ و بادمجان'}
# -----------------------------------------------
# {'resturaunt_day_meal__date': datetime.date(2021, 8, 2), 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه نگینی'}
# -----------------------------------------------
# {'resturaunt_day_meal__date': datetime.date(2021, 8, 3), 'resturaunt_day_meal__resturaunt_meal__name': 'لوبیا پلو با گوشت'}
# -----------------------------------------------
# {'resturaunt_day_meal__date': datetime.date(2021, 8, 4), 'resturaunt_day_meal__resturaunt_meal__name': 'خوراک جوجه لبنانی'}
# -----------------------------------------------
# {'resturaunt_day_meal__date': datetime.date(2021, 8, 7), 'resturaunt_day_meal__resturaunt_meal__name': 'پلو مکزیکی'}
# -----------------------------------------------
# {'resturaunt_day_meal__date': datetime.date(2021, 8, 8), 'resturaunt_day_meal__resturaunt_meal__name': 'دونر کباب'}
# -----------------------------------------------
# {'resturaunt_day_meal__date': datetime.date(2021, 8, 9), 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# -----------------------------------------------
# {'resturaunt_day_meal__date': datetime.date(2021, 8, 10), 'resturaunt_day_meal__resturaunt_meal__name': 'باقالی پلو با مرغ'}
# -----------------------------------------------
# {'resturaunt_day_meal__date': datetime.date(2021, 8, 11), 'resturaunt_day_meal__resturaunt_meal__name': 'خوراک جوجه لبنانی'}
# -----------------------------------------------
# {'resturaunt_day_meal__date': datetime.date(2021, 8, 14), 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان'}
# -----------------------------------------------
# {'resturaunt_day_meal__date': datetime.date(2021, 8, 15), 'resturaunt_day_meal__resturaunt_meal__name': 'لازانیا گوشت'}
# -----------------------------------------------
# {'resturaunt_day_meal__date': datetime.date(2021, 8, 16), 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه کباب زعفرانی'}
# -----------------------------------------------
# {'resturaunt_day_meal__date': datetime.date(2021, 8, 17), 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش فسنجان با مرغ'}
# -----------------------------------------------
# {'resturaunt_day_meal__date': datetime.date(2021, 8, 21), 'resturaunt_day_meal__resturaunt_meal__name': 'باقالی پلو با مرغ'}
# -----------------------------------------------
# {'resturaunt_day_meal__date': datetime.date(2021, 8, 22), 'resturaunt_day_meal__resturaunt_meal__name': 'ته چین مرغ'}
# -----------------------------------------------

# %%
from django.db.models import Count

currentdate = date.today()
results = Resturaunt_Employee_Day_Meal.objects.filter(
    resturaunt_day_meal__date__exact=currentdate).exclude(employee__department__name__exact=None).values(
    'employee__department__name', 'resturaunt_day_meal__resturaunt_meal__name').annotate(
    mealNo=Count('resturaunt_day_meal__resturaunt_meal__name')).order_by('employee__department__name')

# result = (Members.objects
#     .values('designation')
#     .annotate(dcount=Count('designation'))
#     .order_by()
# )

for item in results:
    print(item)
# Out:
# {'employee__department__name': 'اداری و منابع انسانی', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان', 'mealNo': 8}
# {'employee__department__name': 'اداری و منابع انسانی', 'resturaunt_day_meal__resturaunt_meal__name': 'خوراک کوردن بلو', 'mealNo': 1}
# {'employee__department__name': 'اداری و منابع انسانی', 'resturaunt_day_meal__resturaunt_meal__name': 'دونر کباب', 'mealNo': 6}
# {'employee__department__name': 'بازرگانی خارجی', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان', 'mealNo': 3}
# {'employee__department__name': 'بازرگانی خارجی', 'resturaunt_day_meal__resturaunt_meal__name': 'خوراک کوردن بلو', 'mealNo': 1}
# {'employee__department__name': 'بازرگانی خارجی', 'resturaunt_day_meal__resturaunt_meal__name': 'دونر کباب', 'mealNo': 4}
# {'employee__department__name': 'بازرگانی داخلی', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان', 'mealNo': 10}
# {'employee__department__name': 'بازرگانی داخلی', 'resturaunt_day_meal__resturaunt_meal__name': 'دونر کباب', 'mealNo': 3}
# {'employee__department__name': 'حسابرسی داخلی', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان', 'mealNo': 5}
# {'employee__department__name': 'حسابرسی داخلی', 'resturaunt_day_meal__resturaunt_meal__name': 'خوراک کوردن بلو', 'mealNo': 1}
# {'employee__department__name': 'حسابرسی داخلی', 'resturaunt_day_meal__resturaunt_meal__name': 'دونر کباب', 'mealNo': 5}
# {'employee__department__name': 'دبیرخانه', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان', 'mealNo': 10}
# {'employee__department__name': 'دبیرخانه', 'resturaunt_day_meal__resturaunt_meal__name': 'خوراک کوردن بلو', 'mealNo': 1}
# {'employee__department__name': 'دبیرخانه', 'resturaunt_day_meal__resturaunt_meal__name': 'دونر کباب', 'mealNo': 5}
# {'employee__department__name': 'فناوری اطلاعات و ارتباطات', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان', 'mealNo': 1}
# {'employee__department__name': 'فناوری اطلاعات و ارتباطات', 'resturaunt_day_meal__resturaunt_meal__name': 'خوراک کوردن بلو', 'mealNo': 4}
# {'employee__department__name': 'فناوری اطلاعات و ارتباطات', 'resturaunt_day_meal__resturaunt_meal__name': 'دونر کباب', 'mealNo': 4}
# {'employee__department__name': 'فنی و مهندسی', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان', 'mealNo': 5}
# {'employee__department__name': 'فنی و مهندسی', 'resturaunt_day_meal__resturaunt_meal__name': 'خوراک کوردن بلو', 'mealNo': 2}
# {'employee__department__name': 'فنی و مهندسی', 'resturaunt_day_meal__resturaunt_meal__name': 'دونر کباب', 'mealNo': 5}
# {'employee__department__name': 'مالی  (803)', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان', 'mealNo': 4}
# {'employee__department__name': 'مالی  (803)', 'resturaunt_day_meal__resturaunt_meal__name': 'خوراک کوردن بلو', 'mealNo': 4}
# {'employee__department__name': 'مالی  (803)', 'resturaunt_day_meal__resturaunt_meal__name': 'دونر کباب', 'mealNo': 5}
# {'employee__department__name': 'مالی ( 804 )', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان', 'mealNo': 5}
# {'employee__department__name': 'مالی ( 804 )', 'resturaunt_day_meal__resturaunt_meal__name': 'خوراک کوردن بلو', 'mealNo': 1}
# {'employee__department__name': 'مالی ( 804 )', 'resturaunt_day_meal__resturaunt_meal__name': 'دونر کباب', 'mealNo': 5}
# {'employee__department__name': 'مدیریت', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان', 'mealNo': 2}
# {'employee__department__name': 'مدیریت', 'resturaunt_day_meal__resturaunt_meal__name': 'دونر کباب', 'mealNo': 3}
# {'employee__department__name': 'مشاوران', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان', 'mealNo': 4}
# {'employee__department__name': 'مشاوران', 'resturaunt_day_meal__resturaunt_meal__name': 'خوراک کوردن بلو', 'mealNo': 1}

# %%
from django.db.models import Value, SmallIntegerField

currentdate = date.today()
results = Resturaunt_Employee_Day_Meal.objects.filter(resturaunt_day_meal__date__exact=currentdate).exclude(
        employee__department__company__name__exact='آسفالت طوس').exclude(
        employee__project__company__name__exact='آسفالت طوس').values(
        'employee__department').order_by(
        'employee__department__name').annotate(
        section=F('employee__department__name'), 
        meal_name=F('resturaunt_day_meal__resturaunt_meal__name'), 
        meal_no=Count('resturaunt_day_meal__resturaunt_meal__name')).values('section', 'meal_name', 'meal_no')

for item in results:
    print(item)
    print('-------------------------------------------------------------')

# %%
currentdate = date.today()
result = Resturaunt_Employee_Day_Meal.objects.filter(resturaunt_day_meal__date__exact=currentdate).exclude(
        employee__department__company__name__exact='آسفالت طوس').count()
print(result)
# Out:
# 91

# %%
currentdate = date.today()
projectId = 6
# date = datetime.strptime(currentdate, '%Y-%m-%d').date()

result1 = Resturaunt_Day_Meal.objects.filter(date__exact=currentdate)
result = Resturaunt_Employee_Day_Meal.objects.filter(resturaunt_day_meal__in=result1, employee__project_id__exact=projectId).values(
                'employee__first_name', 'employee__last_name', 'resturaunt_day_meal__resturaunt_meal__name')

for item in result1:
    print(item)     
    print('----------------------------------') 
print('#######################################')
for item in result:
    print(item)     
    print('----------------------------------')
# Out:
# Resturaunt_Day_Meal object (60)
# ----------------------------------
# Resturaunt_Day_Meal object (94)
# ----------------------------------
# Resturaunt_Day_Meal object (95)
# ----------------------------------
# #######################################
# {'employee__first_name': 'علی', 'employee__last_name': 'شایگان', 'resturaunt_day_meal__resturaunt_meal__name': 'باقالی پلو با مرغ'}
# ----------------------------------
# {'employee__first_name': 'هادی', 'employee__last_name': 'معظمیان', 'resturaunt_day_meal__resturaunt_meal__name': 'باقالی پلو با مرغ'}
# ----------------------------------
# {'employee__first_name': 'حسین', 'employee__last_name': 'طالبی', 'resturaunt_day_meal__resturaunt_meal__name': 'باقالی پلو با مرغ'}
# ----------------------------------
# {'employee__first_name': 'حسین', 'employee__last_name': 'طالبی', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قیمه نثار'}
# ----------------------------------
# {'employee__first_name': 'احسان', 'employee__last_name': 'علی مددی', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قیمه نثار'}
# ----------------------------------
# {'employee__first_name': 'محسن', 'employee__last_name': 'فرهمند نیکو', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قیمه نثار'}
# ----------------------------------
# {'employee__first_name': 'امیر مسعود', 'employee__last_name': 'رنجبران', 'resturaunt_day_meal__resturaunt_meal__name': 'باقالی پلو با مرغ'}
# ----------------------------------
# {'employee__first_name': 'بهنام', 'employee__last_name': 'باقرزاده', 'resturaunt_day_meal__resturaunt_meal__name': 'باقالی پلو با مرغ'}
# ----------------------------------
# {'employee__first_name': 'محمدرضا', 'employee__last_name': 'تبیانیان', 'resturaunt_day_meal__resturaunt_meal__name': 'باقالی پلو با مرغ'}
# ----------------------------------
# {'employee__first_name': 'فاطمه', 'employee__last_name': 'صبح خیر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قیمه نثار'}
# ----------------------------------
# {'employee__first_name': 'سیما', 'employee__last_name': 'رحیمی', 'resturaunt_day_meal__resturaunt_meal__name': 'باقالی پلو با مرغ'}
# ----------------------------------
# {'employee__first_name': 'حسین', 'employee__last_name': 'غفرانی', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قیمه نثار'}
# ----------------------------------
# {'employee__first_name': 'مصطفی', 'employee__last_name': 'تکریمی', 'resturaunt_day_meal__resturaunt_meal__name': 'باقالی پلو با مرغ'}
# ----------------------------------
# {'employee__first_name': 'نادر', 'employee__last_name': 'گوهری', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قیمه نثار'}
# ----------------------------------
# {'employee__first_name': 'حدیثه', 'employee__last_name': 'حسینی', 'resturaunt_day_meal__resturaunt_meal__name': 'باقالی پلو با مرغ'}
# ----------------------------------
# {'employee__first_name': 'مهدیس', 'employee__last_name': 'رهبر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قیمه نثار'}
# ----------------------------------
# {'employee__first_name': 'داریوش', 'employee__last_name': 'دارایی', 'resturaunt_day_meal__resturaunt_meal__name': 'باقالی پلو با مرغ'}
# ----------------------------------
# {'employee__first_name': 'مجید', 'employee__last_name': 'رزم پوش', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قیمه نثار'}
# ----------------------------------
# {'employee__first_name': 'توحید', 'employee__last_name': 'نیک آمیز', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قیمه نثار'}
# ----------------------------------
# {'employee__first_name': 'نادر', 'employee__last_name': 'سادات امینی', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قیمه نثار'}
# ----------------------------------
# {'employee__first_name': 'عطاالله', 'employee__last_name': 'بلوریان تهرانی', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قیمه نثار'}
# ----------------------------------
# {'employee__first_name': 'محدثه', 'employee__last_name': 'رهبر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قیمه نثار'}
# ----------------------------------
# {'employee__first_name': 'امیر حسین', 'employee__last_name': 'آقاخانی', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قیمه نثار'}
# ----------------------------------
# {'employee__first_name': 'مینو', 'employee__last_name': 'سلطانی', 'resturaunt_day_meal__resturaunt_meal__name': 'باقالی پلو با مرغ'}
# ----------------------------------
# {'employee__first_name': 'الهام', 'employee__last_name': 'اناری', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قیمه نثار'}
# ----------------------------------

# %%
currentdate = date.today()
departmentId = 17
# date = datetime.strptime(currentdate, '%Y-%m-%d').date()

result1 = Resturaunt_Day_Meal.objects.filter(date__exact=currentdate)
for item in result1:
    print(item)
result = Resturaunt_Employee_Day_Meal.objects.filter(resturaunt_day_meal__in=result1, employee__department_id__exact=departmentId).values(
                    'employee__first_name', 'employee__last_name', 'resturaunt_day_meal__resturaunt_meal__name')
for item in result:
    print(item)
# Out:
# Resturaunt_Day_Meal object (61)
# Resturaunt_Day_Meal object (96)
# Resturaunt_Day_Meal object (97)
