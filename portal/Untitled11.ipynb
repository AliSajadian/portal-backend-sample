# %%
import urllib

params = 'DRIVER={ODBC Driver 13 for SQL Server};' \
         'SERVER=localhost;' \
         'PORT=1433;' \
         'DATABASE=DbAsftPortal;' \
         'UID=sa;' \
         'PWD=aSj#14776$10036%mM&;'
            
params = urllib.parse.quote_plus(params)

from sqlalchemy import create_engine

db = create_engine('mssql+pyodbc:///?odbc_connect=%s' % params)

import pandas as pd

sql = '''
SELECT TABLE_NAME
FROM INFORMATION_SCHEMA.TABLES
WHERE TABLE_TYPE = 'BASE TABLE' AND TABLE_CATALOG='DbAsftPortal'
'''

pd.read_sql_query(sql, db)
# Out:
#                                 TABLE_NAME
# 0                           knox_authtoken
# 1                         tbl_library_book
# 2                  tbl_library_book_author
# 3               tbl_library_book_publisher
# 4                    tbl_library_book_type
# 5                  tbl_library_loaned_book
# 6                   tbl_meeting_cater_type
# 7                    tbl_meeting_equipment
# 8                      tbl_meeting_request
# 9                         tbl_meeting_room
# 10                   tbl_meeting_room_type
# 11              tbl_meeting_room_equipment
# 12          tbl_meeting_request_cater_type
# 13                 tbl_resturaunt_day_meal
# 14                       django_migrations
# 15           tbl_resturaunt_guest_day_meal
# 16                     django_content_type
# 17                     tbl_resturaunt_meal
# 18                         auth_permission
# 19  tbl_resturaunt_guest_day_meal_junction
# 20                              auth_group
# 21        tbl_resturaunt_employee_day_meal
# 22                  auth_group_permissions
# 23                               auth_user
# 24                        auth_user_groups
# 25              auth_user_user_permissions
# 26                          django_session
# 27                       tbl_survey_answer
# 28                     tbl_survey_question
# 29                       tbl_survey_survey
# 30                        django_admin_log
# 31                  tbl_survey_user_answer
# 32                   tbl_survey_department
# 33                        tbl_base_company
# 34                     tbl_base_department
# 35                          tbl_doctorType
# 36                    tbl_base_jobPosition
# 37                          tbl_surveyType
# 38                        tbl_base_project
# 39                   tbl_base_notification
# 40                       tbl_base_employee
# 41           tbl_meeting_request_equipment
# 42                    tbl_doc_appointments
# 43                             tbl_doctors
# 44               tbl_doc_schedule_weekdays
# 45                   tbl_doc_schedule_days
# 46                  tbl_doc_patients_files
# 47                        tbl_doc_patients
# 48               tbl_doc_appointment_times

# %%
import os
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

from datetime import datetime, date
from resturaunt.models import Resturaunt_Meal, Resturaunt_Day_Meal, Resturaunt_Employee_Day_Meal, Resturaunt_Guest_Day_Meal_Junction, Resturaunt_Guest_Day_Meal

currentdate = date.today()
departmentId = 17
# date = datetime.strptime(currentdate, '%Y-%m-%d').date()

result1 = Resturaunt_Day_Meal.objects.filter(date__exact=currentdate)
result = Resturaunt_Employee_Day_Meal.objects.filter(resturaunt_day_meal__in=result1, employee__department_id__exact=departmentId).values(
                    'employee__first_name', 'employee__last_name', 'resturaunt_day_meal__resturaunt_meal__name')
for item in result:
    print(item)    
    print('===============================')
# Out:
# {'employee__first_name': 'قاسم', 'employee__last_name': 'ميرحسني ناوان', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# ===============================
# {'employee__first_name': 'سعید', 'employee__last_name': 'غلامی', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# ===============================
# {'employee__first_name': 'فاطمه', 'employee__last_name': 'نعمت زاده قره داغلو', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# ===============================
# {'employee__first_name': 'مژگان', 'employee__last_name': 'پرهیزکاری', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# ===============================
# {'employee__first_name': 'توحيد', 'employee__last_name': 'عبادي دمدل', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# ===============================
# {'employee__first_name': 'نرجس', 'employee__last_name': 'مشتوفر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# ===============================
# {'employee__first_name': 'شيوا', 'employee__last_name': 'مهربان بوشهري', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# ===============================
# {'employee__first_name': 'حسين', 'employee__last_name': 'پارسا مهر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# ===============================
# {'employee__first_name': 'عباس', 'employee__last_name': 'برجي', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# ===============================
# {'employee__first_name': 'علی', 'employee__last_name': 'حسینی', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# ===============================
# {'employee__first_name': 'وحيد', 'employee__last_name': 'غلامی لاکه', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# ===============================
# {'employee__first_name': 'مهدي', 'employee__last_name': 'نجفيان', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# ===============================
# {'employee__first_name': 'آرش', 'employee__last_name': 'اسدزاده صدفي', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# ===============================
# {'employee__first_name': 'سپهر', 'employee__last_name': 'قوی روح', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# ===============================
# {'employee__first_name': 'مجتبی', 'employee__last_name': 'مردانی', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# ===============================
# {'employee__first_name': 'جعفر', 'employee__last_name': 'اعلائي سرچشمه', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان'}
# ===============================
# {'employee__first_name': 'عسگر', 'employee__last_name': 'نصیری', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان'}
# ===============================
# {'employee__first_name': 'مريم', 'employee__last_name': 'قديريان قديري', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان'}
# ===============================
# {'employee__first_name': 'علي محمد', 'employee__last_name': 'اوليايي', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان'}
# ===============================
# {'employee__first_name': 'علي', 'employee__last_name': 'جانانه', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان'}
# ===============================
# {'employee__first_name': 'نگار', 'employee__last_name': 'رهبري دولق', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان'}
# ===============================
# {'employee__first_name': 'فائقه', 'employee__last_name': 'منصوري فعال', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان'}
# ===============================
# {'employee__first_name': 'مهديه', 'employee__last_name': 'رفيعي يگانه', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان'}
# ===============================
# {'employee__first_name': 'امير', 'employee__last_name': 'خادمان', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان'}
# ===============================
# {'employee__first_name': 'عادل', 'employee__last_name': 'محمد آبادی کمره', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان'}
# ===============================
# {'employee__first_name': 'سيد مهدي', 'employee__last_name': 'محسني', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان'}
# ===============================
# {'employee__first_name': 'معين', 'employee__last_name': 'عسگري', 'resturaunt_day_meal__resturaunt_meal__name': 'کوکو سبزی'}
# ===============================

# %%
currentdate = date.today()
y = currentdate.year
m = currentdate.month - 1
d = currentdate.day
startdate = ""
enddate = ""
if(m == 1):
    startdate += str(y) 
    startdate += "-01" if (d < 21) else "-02" 
    startdate += "-21" if (d < 21) else "-20"
    enddate += str(y) 
    enddate += "-02" if (d < 21) else "-03" 
    enddate += "-19" if (d < 21) else "-20"
elif(m == 2):
    startdate += str(y) 
    startdate += "-02" if (d < 20) else "-03" 
    startdate += "-20" if (d < 20) else "-21"
    enddate += str(y) 
    enddate += "-03" if (d < 20) else "-04" 
    enddate += "-20" if (d < 20) else "-20"
elif(m == 3):
    startdate += str(y) 
    startdate += "-03" if (d < 21) else "-04" 
    startdate += "-21" if (d < 21) else "-21"
    enddate += str(y) 
    enddate += "-04" if (d < 21) else "-05" 
    enddate += "-21" if (d < 21) else "-21"
elif(m == 4):
    startdate += str(y) 
    startdate += "-04" if (d < 21) else "-05" 
    startdate += "-21" if (d < 21) else "-22"
    enddate += str(y) 
    enddate += "-05" if (d < 21) else "-06" 
    enddate += "-21" if (d < 21) else "-21"            
elif(m == 5):
    startdate += str(y) 
    startdate += "-05" if (d < 22) else "-06" 
    startdate += "-22" if (d < 22) else "-22" 
    enddate += str(y) 
    enddate += "-06" if (d < 22) else "-07" 
    enddate += "-21" if (d < 22) else "-22"            
elif(m == 6):
    startdate += str(y) 
    startdate += "-06" if (d < 22) else "-07" 
    startdate += "-22" if (d < 22) else "-23" 
    enddate += str(y) 
    enddate += "-07" if (d < 22) else "-08" 
    enddate += "-22" if (d < 22) else "-22"            
elif(m == 7):
    startdate += str(y) 
    startdate += "-07" if (d < 23) else "-08" 
    startdate += "-23" if (d < 23) else "-23" 
    enddate += str(y) 
    enddate += "-08" if (d < 23) else "-09" 
    enddate += "-22" if (d < 23) else "-22"            
elif(m == 8):
    startdate += str(y) 
    startdate += "-08" if (d < 23) else "-09" 
    startdate += "-23" if (d < 23) else "-23" 
    enddate += str(y) 
    enddate += "-09" if (d < 21) else "-10" 
    enddate += "-22" if (d < 21) else "-22"
elif(m == 9):
    startdate = str(y) 
    startdate += "-09" if (d < 23) else "-10" 
    startdate += "-23" if (d < 23) else "-23" 
    enddate += str(y) 
    enddate += "-10" if (d < 21) else "-11" 
    enddate += "-22" if (d < 21) else "-21"            
elif(m == 10):
    startdate += str(y) 
    startdate += "-10" if (d < 23) else "-11" 
    startdate += "-23" if (d < 23) else "-22" 
    enddate += str(y) 
    enddate += "-11" if (d < 21) else "-12" 
    enddate += "-21" if (d < 21) else "-21"            
elif(m == 11):
    startdate += str(y) 
    startdate += "-11" if (d < 22) else "-12" 
    startdate += "-22" if (d < 22) else "-22" 
    enddate += str(y) 
    enddate += "-12" if (d < 21) else "-01" 
    enddate += "-21" if (d < 21) else "-20"
elif(m == 12):
    startdate += str(y) 
    startdate += "-12" if (d < 22) else "-01" 
    startdate += "-22" if (d < 22) else "-21"
    enddate += str(y) 
    enddate += "-01" if (d < 21) else "-02" 
    enddate += "-20" if (d < 21) else "-19"             

employee_id = 1585
result = Resturaunt_Employee_Day_Meal.objects.filter(employee=employee_id,
                                                     resturaunt_day_meal__date__gte=startdate, 
                                                     resturaunt_day_meal__date__lte=enddate).values(
    'id', 'employee', 'resturaunt_day_meal')
# .order_by('-id')

print(startdate)
print(enddate)
for item in result:
    print(item)
    print('======================================================')
# Out:
# 2021-08-23
# 2021-09-22
# {'id': 4621, 'employee': 1585, 'resturaunt_day_meal': 182}
# ======================================================
# {'id': 4622, 'employee': 1585, 'resturaunt_day_meal': 124}
# ======================================================
# {'id': 4623, 'employee': 1585, 'resturaunt_day_meal': 189}
# ======================================================
# {'id': 4624, 'employee': 1585, 'resturaunt_day_meal': 176}
# ======================================================
# {'id': 4625, 'employee': 1585, 'resturaunt_day_meal': 131}
# ======================================================
# {'id': 4626, 'employee': 1585, 'resturaunt_day_meal': 192}
# ======================================================
# {'id': 4627, 'employee': 1585, 'resturaunt_day_meal': 201}
# ======================================================
# {'id': 4628, 'employee': 1585, 'resturaunt_day_meal': 132}
# ======================================================
# {'id': 4629, 'employee': 1585, 'resturaunt_day_meal': 155}
# ======================================================
# {'id': 4630, 'employee': 1585, 'resturaunt_day_meal': 159}
# ======================================================
# {'id': 4631, 'employee': 1585, 'resturaunt_day_meal': 174}
# ======================================================
# {'id': 4632, 'employee': 1585, 'resturaunt_day_meal': 142}
# ======================================================
# {'id': 4633, 'employee': 1585, 'resturaunt_day_meal': 181}
# ======================================================
# {'id': 4634, 'employee': 1585, 'resturaunt_day_meal': 138}
# ======================================================
# {'id': 4635, 'employee': 1585, 'resturaunt_day_meal': 188}
# ======================================================
# {'id': 4636, 'employee': 1585, 'resturaunt_day_meal': 196}
# ======================================================
# {'id': 4637, 'employee': 1585, 'resturaunt_day_meal': 199}
# ======================================================
# {'id': 4638, 'employee': 1585, 'resturaunt_day_meal': 135}
# ======================================================
# {'id': 4639, 'employee': 1585, 'resturaunt_day_meal': 161}
# ======================================================
# {'id': 4640, 'employee': 1585, 'resturaunt_day_meal': 164}
# ======================================================
# {'id': 4641, 'employee': 1585, 'resturaunt_day_meal': 149}
# ======================================================
# {'id': 4642, 'employee': 1585, 'resturaunt_day_meal': 167}
# ======================================================
# {'id': 4643, 'employee': 1585, 'resturaunt_day_meal': 170}
# ======================================================

# %%
currentdate = date.today()
y = currentdate.year
m = currentdate.month-1
d = currentdate.day
startdate = ""
enddate = ""
if(m == 1):
    startdate += str(y) 
    startdate += "-01" if (d < 21) else "-02" 
    startdate += "-21" if (d < 21) else "-20"
    enddate += str(y) 
    enddate += "-02" if (d < 21) else "-03" 
    enddate += "-19" if (d < 21) else "-20"
elif(m == 2):
    startdate += str(y) 
    startdate += "-02" if (d < 20) else "-03" 
    startdate += "-20" if (d < 20) else "-21"
    enddate += str(y) 
    enddate += "-03" if (d < 20) else "-04" 
    enddate += "-20" if (d < 20) else "-20"
elif(m == 3):
    startdate += str(y) 
    startdate += "-03" if (d < 21) else "-04" 
    startdate += "-21" if (d < 21) else "-21"
    enddate += str(y) 
    enddate += "-04" if (d < 21) else "-05" 
    enddate += "-21" if (d < 21) else "-21"
elif(m == 4):
    startdate += str(y) 
    startdate += "-04" if (d < 21) else "-05" 
    startdate += "-21" if (d < 21) else "-22"
    enddate += str(y) 
    enddate += "-05" if (d < 21) else "-06" 
    enddate += "-21" if (d < 21) else "-21"            
elif(m == 5):
    startdate += str(y) 
    startdate += "-05" if (d < 22) else "-06" 
    startdate += "-22" if (d < 22) else "-22" 
    enddate += str(y) 
    enddate += "-06" if (d < 22) else "-07" 
    enddate += "-21" if (d < 22) else "-22"            
elif(m == 6):
    startdate += str(y) 
    startdate += "-06" if (d < 22) else "-07" 
    startdate += "-22" if (d < 22) else "-23" 
    enddate += str(y) 
    enddate += "-07" if (d < 22) else "-08" 
    enddate += "-22" if (d < 22) else "-22"            
elif(m == 7):
    startdate += str(y) 
    startdate += "-07" if (d < 23) else "-08" 
    startdate += "-23" if (d < 23) else "-23" 
    enddate += str(y) 
    enddate += "-08" if (d < 23) else "-09" 
    enddate += "-22" if (d < 23) else "-22"            
elif(m == 8):
    startdate += str(y) 
    startdate += "-08" if (d < 23) else "-09" 
    startdate += "-23" if (d < 23) else "-23" 
    enddate += str(y) 
    enddate += "-09" if (d < 21) else "-10" 
    enddate += "-22" if (d < 21) else "-22"
elif(m == 9):
    startdate = str(y) 
    startdate += "-09" if (d < 23) else "-10" 
    startdate += "-23" if (d < 23) else "-23" 
    enddate += str(y) 
    enddate += "-10" if (d < 21) else "-11" 
    enddate += "-22" if (d < 21) else "-21"            
elif(m == 10):
    startdate += str(y) 
    startdate += "-10" if (d < 23) else "-11" 
    startdate += "-23" if (d < 23) else "-22" 
    enddate += str(y) 
    enddate += "-11" if (d < 21) else "-12" 
    enddate += "-21" if (d < 21) else "-21"            
elif(m == 11):
    startdate += str(y) 
    startdate += "-11" if (d < 22) else "-12" 
    startdate += "-22" if (d < 22) else "-22" 
    enddate += str(y) 
    enddate += "-12" if (d < 21) else "-01" 
    enddate += "-21" if (d < 21) else "-20"
elif(m == 12):
    startdate += str(y) 
    startdate += "-12" if (d < 22) else "-01" 
    startdate += "-22" if (d < 22) else "-21"
    enddate += str(y) 
    enddate += "-01" if (d < 21) else "-02" 
    enddate += "-20" if (d < 21) else "-19"             

print(startdate)
print(enddate)
result = Resturaunt_Day_Meal.objects.filter(date__gte=startdate, date__lte=enddate)
print(len(result))
for item in result:
    print(item)
    print('======================')
# Out:
# 2021-08-23
# 2021-09-22
# 116
# Resturaunt_Day_Meal object (124)
# ======================
# Resturaunt_Day_Meal object (127)
# ======================
# Resturaunt_Day_Meal object (128)
# ======================
# Resturaunt_Day_Meal object (129)
# ======================
# Resturaunt_Day_Meal object (130)
# ======================
# Resturaunt_Day_Meal object (131)
# ======================
# Resturaunt_Day_Meal object (132)
# ======================
# Resturaunt_Day_Meal object (133)
# ======================
# Resturaunt_Day_Meal object (134)
# ======================
# Resturaunt_Day_Meal object (135)
# ======================
# Resturaunt_Day_Meal object (136)
# ======================
# Resturaunt_Day_Meal object (137)
# ======================
# Resturaunt_Day_Meal object (138)
# ======================
# Resturaunt_Day_Meal object (139)
# ======================
# Resturaunt_Day_Meal object (140)
# ======================
# Resturaunt_Day_Meal object (142)
# ======================
# Resturaunt_Day_Meal object (143)
# ======================
# Resturaunt_Day_Meal object (144)
# ======================
# Resturaunt_Day_Meal object (149)
# ======================
# Resturaunt_Day_Meal object (151)
# ======================
# Resturaunt_Day_Meal object (154)
# ======================
# Resturaunt_Day_Meal object (155)
# ======================
# Resturaunt_Day_Meal object (156)
# ======================
# Resturaunt_Day_Meal object (157)
# ======================
# Resturaunt_Day_Meal object (158)
# ======================
# Resturaunt_Day_Meal object (159)
# ======================
# Resturaunt_Day_Meal object (160)
# ======================
# Resturaunt_Day_Meal object (161)
# ======================
# Resturaunt_Day_Meal object (162)
# ======================
# Resturaunt_Day_Meal object (163)
# ======================
# Resturaunt_Day_Meal object (164)
# ======================
# Resturaunt_Day_Meal object (165)
# ======================
# Resturaunt_Day_Meal object (166)
# ======================
# Resturaunt_Day_Meal object (167)
# ======================
# Resturaunt_Day_Meal object (168)
# ======================
# Resturaunt_Day_Meal object (169)
# ======================
# Resturaunt_Day_Meal object (170)
# ======================
# Resturaunt_Day_Meal object (173)
# ======================
# Resturaunt_Day_Meal object (174)
# ======================
# Resturaunt_Day_Meal object (175)
# ======================
# Resturaunt_Day_Meal object (176)
# ======================
# Resturaunt_Day_Meal object (177)
# ======================
# Resturaunt_Day_Meal object (178)
# ======================
# Resturaunt_Day_Meal object (179)
# ======================
# Resturaunt_Day_Meal object (180)
# ======================
# Resturaunt_Day_Meal object (181)
# ======================
# Resturaunt_Day_Meal object (182)
# ======================
# Resturaunt_Day_Meal object (183)
# ======================
# Resturaunt_Day_Meal object (184)
# ======================
# Resturaunt_Day_Meal object (186)
# ======================
# Resturaunt_Day_Meal object (187)
# ======================
# Resturaunt_Day_Meal object (188)
# ======================
# Resturaunt_Day_Meal object (189)
# ======================
# Resturaunt_Day_Meal object (190)
# ======================
# Resturaunt_Day_Meal object (191)
# ======================
# Resturaunt_Day_Meal object (192)
# ======================
# Resturaunt_Day_Meal object (193)
# ======================
# Resturaunt_Day_Meal object (194)
# ======================
# Resturaunt_Day_Meal object (195)
# ======================
# Resturaunt_Day_Meal object (196)
# ======================
# Resturaunt_Day_Meal object (198)
# ======================
# Resturaunt_Day_Meal object (199)
# ======================
# Resturaunt_Day_Meal object (200)
# ======================
# Resturaunt_Day_Meal object (201)
# ======================
# Resturaunt_Day_Meal object (202)
# ======================
# Resturaunt_Day_Meal object (204)
# ======================
# Resturaunt_Day_Meal object (205)
# ======================
# Resturaunt_Day_Meal object (206)
# ======================
# Resturaunt_Day_Meal object (207)
# ======================
# Resturaunt_Day_Meal object (208)
# ======================
# Resturaunt_Day_Meal object (209)
# ======================
# Resturaunt_Day_Meal object (210)
# ======================
# Resturaunt_Day_Meal object (211)
# ======================
# Resturaunt_Day_Meal object (213)
# ======================
# Resturaunt_Day_Meal object (214)
# ======================
# Resturaunt_Day_Meal object (215)
# ======================
# Resturaunt_Day_Meal object (216)
# ======================
# Resturaunt_Day_Meal object (217)
# ======================
# Resturaunt_Day_Meal object (218)
# ======================
# Resturaunt_Day_Meal object (219)
# ======================
# Resturaunt_Day_Meal object (220)
# ======================
# Resturaunt_Day_Meal object (221)
# ======================
# Resturaunt_Day_Meal object (222)
# ======================
# Resturaunt_Day_Meal object (223)
# ======================
# Resturaunt_Day_Meal object (224)
# ======================
# Resturaunt_Day_Meal object (225)
# ======================
# Resturaunt_Day_Meal object (226)
# ======================
# Resturaunt_Day_Meal object (227)
# ======================
# Resturaunt_Day_Meal object (228)
# ======================
# Resturaunt_Day_Meal object (229)
# ======================
# Resturaunt_Day_Meal object (230)
# ======================
# Resturaunt_Day_Meal object (231)
# ======================
# Resturaunt_Day_Meal object (232)
# ======================
# Resturaunt_Day_Meal object (233)
# ======================
# Resturaunt_Day_Meal object (234)
# ======================
# Resturaunt_Day_Meal object (235)
# ======================
# Resturaunt_Day_Meal object (236)
# ======================
# Resturaunt_Day_Meal object (237)
# ======================
# Resturaunt_Day_Meal object (238)
# ======================
# Resturaunt_Day_Meal object (239)
# ======================
# Resturaunt_Day_Meal object (240)
# ======================
# Resturaunt_Day_Meal object (241)
# ======================
# Resturaunt_Day_Meal object (242)
# ======================
# Resturaunt_Day_Meal object (243)
# ======================
# Resturaunt_Day_Meal object (244)
# ======================
# Resturaunt_Day_Meal object (245)
# ======================
# Resturaunt_Day_Meal object (246)
# ======================
# Resturaunt_Day_Meal object (247)
# ======================
# Resturaunt_Day_Meal object (248)
# ======================
# Resturaunt_Day_Meal object (249)
# ======================
# Resturaunt_Day_Meal object (250)
# ======================
# Resturaunt_Day_Meal object (251)
# ======================
# Resturaunt_Day_Meal object (252)
# ======================
# Resturaunt_Day_Meal object (253)
# ======================
# Resturaunt_Day_Meal object (254)
# ======================
# Resturaunt_Day_Meal object (255)
# ======================

# %%
from resturaunt.models import Resturaunt_Employee_Day_Meal
{
    "personelMealDays":[
        {"employee":1,"resturaunt_day_meal":124},
        {"employee":1,"resturaunt_day_meal":129},
        {"employee":1,"resturaunt_day_meal":132},
        {"employee":1,"resturaunt_day_meal":135},
        {"employee":1,"resturaunt_day_meal":138},
        {"employee":1,"resturaunt_day_meal":142},
        {"employee":1,"resturaunt_day_meal":149},
        {"employee":1,"resturaunt_day_meal":151},
        {"employee":1,"resturaunt_day_meal":158},
        {"employee":1,"resturaunt_day_meal":161},
        {"employee":1,"resturaunt_day_meal":164},
        {"employee":1,"resturaunt_day_meal":167},
        {"employee":1,"resturaunt_day_meal":170},
        {"employee":1,"resturaunt_day_meal":173},
        {"employee":1,"resturaunt_day_meal":176},
        {"employee":1,"resturaunt_day_meal":179},
        {"employee":1,"resturaunt_day_meal":182},
        {"employee":1,"resturaunt_day_meal":186},
        {"employee":1,"resturaunt_day_meal":193},
        {"employee":1,"resturaunt_day_meal":190},
        {"employee":1,"resturaunt_day_meal":196},
        {"employee":1,"resturaunt_day_meal":200},
        {"employee":1,"resturaunt_day_meal":202}
    ],
    "editMood":True
}

# import json
# data = json.loads(x)
# data = request.data
# request.POST.getlist('personelMealDays')

# from itertools import islice

personelMealDays = data["personelMealDays"]

# objs = []
# for pmd in personelMealDays:
#     obj = Resturaunt_Employee_Day_Meal.objects.get(id=pmd['id'])
#     obj.resturaunt_day_meal_id = pmd['resturaunt_day_meal']
#     objs.append(obj)
# Resturaunt_Employee_Day_Meal.objects.bulk_update(objs, ['resturaunt_day_meal'])

objs = []
for pmd in personelMealDays:
    obj = Resturaunt_Employee_Day_Meal(employee_id=pmd['employee'], resturaunt_day_meal_id=pmd['resturaunt_day_meal'])
    objs.append(obj)
    emp = pmd['employee']
Resturaunt_Employee_Day_Meal.objects.bulk_create(objs)  

currentdate = date.today()
y = currentdate.year
m = currentdate.month-1
d = currentdate.day
startdate = ""
enddate = ""
if(m == 1):
    startdate += str(y) 
    startdate += "-01" if (d < 21) else "-02" 
    startdate += "-21" if (d < 21) else "-20"
    enddate += str(y) 
    enddate += "-02" if (d < 21) else "-03" 
    enddate += "-19" if (d < 21) else "-20"
elif(m == 2):
    startdate += str(y) 
    startdate += "-02" if (d < 20) else "-03" 
    startdate += "-20" if (d < 20) else "-21"
    enddate += str(y) 
    enddate += "-03" if (d < 20) else "-04" 
    enddate += "-20" if (d < 20) else "-20"
elif(m == 3):
    startdate += str(y) 
    startdate += "-03" if (d < 21) else "-04" 
    startdate += "-21" if (d < 21) else "-21"
    enddate += str(y) 
    enddate += "-04" if (d < 21) else "-05" 
    enddate += "-21" if (d < 21) else "-21"
elif(m == 4):
    startdate += str(y) 
    startdate += "-04" if (d < 21) else "-05" 
    startdate += "-21" if (d < 21) else "-22"
    enddate += str(y) 
    enddate += "-05" if (d < 21) else "-06" 
    enddate += "-21" if (d < 21) else "-21"            
elif(m == 5):
    startdate += str(y) 
    startdate += "-05" if (d < 22) else "-06" 
    startdate += "-22" if (d < 22) else "-22" 
    enddate += str(y) 
    enddate += "-06" if (d < 22) else "-07" 
    enddate += "-21" if (d < 22) else "-22"            
elif(m == 6):
    startdate += str(y) 
    startdate += "-06" if (d < 22) else "-07" 
    startdate += "-22" if (d < 22) else "-23" 
    enddate += str(y) 
    enddate += "-07" if (d < 22) else "-08" 
    enddate += "-22" if (d < 22) else "-22"            
elif(m == 7):
    startdate += str(y) 
    startdate += "-07" if (d < 23) else "-08" 
    startdate += "-23" if (d < 23) else "-23" 
    enddate += str(y) 
    enddate += "-08" if (d < 23) else "-09" 
    enddate += "-22" if (d < 23) else "-22"            
elif(m == 8):
    startdate += str(y) 
    startdate += "-08" if (d < 23) else "-09" 
    startdate += "-23" if (d < 23) else "-23" 
    enddate += str(y) 
    enddate += "-09" if (d < 21) else "-10" 
    enddate += "-22" if (d < 21) else "-22"
elif(m == 9):
    startdate = str(y) 
    startdate += "-09" if (d < 23) else "-10" 
    startdate += "-23" if (d < 23) else "-23" 
    enddate += str(y) 
    enddate += "-10" if (d < 21) else "-11" 
    enddate += "-22" if (d < 21) else "-21"            
elif(m == 10):
    startdate += str(y) 
    startdate += "-10" if (d < 23) else "-11" 
    startdate += "-23" if (d < 23) else "-22" 
    enddate += str(y) 
    enddate += "-11" if (d < 21) else "-12" 
    enddate += "-21" if (d < 21) else "-21"            
elif(m == 11):
    startdate += str(y) 
    startdate += "-11" if (d < 22) else "-12" 
    startdate += "-22" if (d < 22) else "-22" 
    enddate += str(y) 
    enddate += "-12" if (d < 21) else "-01" 
    enddate += "-21" if (d < 21) else "-20"
elif(m == 12):
    startdate += str(y) 
    startdate += "-12" if (d < 22) else "-01" 
    startdate += "-22" if (d < 22) else "-21"
    enddate += str(y) 
    enddate += "-01" if (d < 21) else "-02" 
    enddate += "-20" if (d < 21) else "-19"             

employee_id = 1585
result = Resturaunt_Employee_Day_Meal.objects.filter(employee=employee_id, 
    resturaunt_day_meal__date__gte=startdate, resturaunt_day_meal__date__lte=enddate).values('id', 'employee', 'resturaunt_day_meal')                     

for item in result:
    print(item)
    print('=====================================')
# for item in personelMealDays:
#     print(item)
# editMood = False
# # print('personelMealDays: ', personelMealDays)
# if(editMood):
#     objs = (Resturaunt_Employee_Day_Meal(employee=model.employee, resturaunt_day_meal=model.resturaunt_day_meal) for model in personelMealDays)
#     batch = list(islice(objs, 0))
#     while True:
#         if not batch:
#             break
#         Resturaunt_Employee_Day_Meal.objects.bulk_create(batch)
# else:
# #     try:
#         objs = (Resturaunt_Employee_Day_Meal(id=pmd.id, employee=pmd.employee, resturaunt_day_meal=pmd.resturaunt_day_meal) for pmd in personelMealDays)
#         for item in objs:
#             print(item)
#         print('objs: ', objs)
#         batch = list(islice(objs, 0))
#         print('batch: ', batch)

#         while True:
#             if not personelMealDays:
#                 break
#             Resturaunt_Employee_Day_Meal.objects.bulk_update(list(personelMealDays), ['resturaunt_day_meal'])                
#     except Exception as e:
#         print(e)
# Out:
# {'id': 4621, 'employee': 1585, 'resturaunt_day_meal': 182}
# =====================================
# {'id': 4622, 'employee': 1585, 'resturaunt_day_meal': 124}
# =====================================
# {'id': 4623, 'employee': 1585, 'resturaunt_day_meal': 189}
# =====================================
# {'id': 4624, 'employee': 1585, 'resturaunt_day_meal': 176}
# =====================================
# {'id': 4625, 'employee': 1585, 'resturaunt_day_meal': 131}
# =====================================
# {'id': 4626, 'employee': 1585, 'resturaunt_day_meal': 193}
# =====================================
# {'id': 4627, 'employee': 1585, 'resturaunt_day_meal': 201}
# =====================================
# {'id': 4628, 'employee': 1585, 'resturaunt_day_meal': 132}
# =====================================
# {'id': 4629, 'employee': 1585, 'resturaunt_day_meal': 155}
# =====================================
# {'id': 4630, 'employee': 1585, 'resturaunt_day_meal': 159}
# =====================================
# {'id': 4631, 'employee': 1585, 'resturaunt_day_meal': 174}
# =====================================
# {'id': 4632, 'employee': 1585, 'resturaunt_day_meal': 142}
# =====================================
# {'id': 4633, 'employee': 1585, 'resturaunt_day_meal': 181}
# =====================================
# {'id': 4634, 'employee': 1585, 'resturaunt_day_meal': 138}
# =====================================
# {'id': 4635, 'employee': 1585, 'resturaunt_day_meal': 188}
# =====================================
# {'id': 4636, 'employee': 1585, 'resturaunt_day_meal': 195}
# =====================================
# {'id': 4637, 'employee': 1585, 'resturaunt_day_meal': 200}
# =====================================
# {'id': 4638, 'employee': 1585, 'resturaunt_day_meal': 135}
# =====================================
# {'id': 4639, 'employee': 1585, 'resturaunt_day_meal': 161}
# =====================================
# {'id': 4640, 'employee': 1585, 'resturaunt_day_meal': 164}
# =====================================
# {'id': 4641, 'employee': 1585, 'resturaunt_day_meal': 149}
# =====================================
# {'id': 4642, 'employee': 1585, 'resturaunt_day_meal': 167}
# =====================================
# {'id': 4643, 'employee': 1585, 'resturaunt_day_meal': 170}
# =====================================
# {'id': 11501, 'employee': 1585, 'resturaunt_day_meal': 182}
# =====================================
# {'id': 11502, 'employee': 1585, 'resturaunt_day_meal': 124}
# =====================================
# {'id': 11503, 'employee': 1585, 'resturaunt_day_meal': 189}
# =====================================
# {'id': 11504, 'employee': 1585, 'resturaunt_day_meal': 176}
# =====================================
# {'id': 11505, 'employee': 1585, 'resturaunt_day_meal': 131}
# =====================================
# {'id': 11506, 'employee': 1585, 'resturaunt_day_meal': 201}
# =====================================
# {'id': 11507, 'employee': 1585, 'resturaunt_day_meal': 132}
# =====================================
# {'id': 11508, 'employee': 1585, 'resturaunt_day_meal': 155}
# =====================================
# {'id': 11509, 'employee': 1585, 'resturaunt_day_meal': 159}
# =====================================
# {'id': 11510, 'employee': 1585, 'resturaunt_day_meal': 174}
# =====================================
# {'id': 11511, 'employee': 1585, 'resturaunt_day_meal': 142}
# =====================================
# {'id': 11512, 'employee': 1585, 'resturaunt_day_meal': 181}
# =====================================
# {'id': 11513, 'employee': 1585, 'resturaunt_day_meal': 138}
# =====================================
# {'id': 11514, 'employee': 1585, 'resturaunt_day_meal': 188}
# =====================================
# {'id': 11515, 'employee': 1585, 'resturaunt_day_meal': 196}
# =====================================
# {'id': 11516, 'employee': 1585, 'resturaunt_day_meal': 199}
# =====================================
# {'id': 11517, 'employee': 1585, 'resturaunt_day_meal': 135}
# =====================================
# {'id': 11518, 'employee': 1585, 'resturaunt_day_meal': 161}
# =====================================
# {'id': 11519, 'employee': 1585, 'resturaunt_day_meal': 170}
# =====================================
# {'id': 11520, 'employee': 1585, 'resturaunt_day_meal': 192}
# =====================================
# {'id': 11521, 'employee': 1585, 'resturaunt_day_meal': 195}
# =====================================
# {'id': 11522, 'employee': 1585, 'resturaunt_day_meal': 200}
# =====================================
# {'id': 11523, 'employee': 1585, 'resturaunt_day_meal': 189}
# =====================================

# %%
currentdate = date.today()
departmentId = 1
# date = datetime.strptime(currentdate, '%Y-%m-%d').date()
print(currentdate)
result1 = Resturaunt_Day_Meal.objects.filter(date__exact=currentdate)
result = Resturaunt_Employee_Day_Meal.objects.filter(resturaunt_day_meal__in=result1, employee__department_id__exact=departmentId).values(
                    'employee__first_name', 'employee__last_name', 'resturaunt_day_meal__resturaunt_meal__name')
# for item in result:
#     print(item)                   
#     print('--------------------------')

result2 = Resturaunt_Employee_Day_Meal.objects.filter(employee_id__exact=1049).values(
                    'employee__first_name', 'employee__last_name', 'resturaunt_day_meal__resturaunt_meal__name')
for item in result2:
    print(item)                   
    print('--------------------------')
# Out:
# 2021-08-31
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش فسنجان با گوشت'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش کرفس'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قیمه نثار'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه غوره بادمجان'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه نگینی'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش فسنجان با مرغ'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو کباب لقمه'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش آلو اسفناج'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه کباب فسنجانی'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'باقالی پلو با مرغ'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش فسنجان با گوشت'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'شیرین پلو با مرغ'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش مرغ و آلو'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه کباب زعفرانی'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قورمه سبزی'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه کباب فسنجانی'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'زرشک پلو با مرغ'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قورمه سبزی'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش قیمه بادمجان'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'خوراک جوجه لبنانی'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'شنیسل مرغ'}
# --------------------------
# {'employee__first_name': 'علی', 'employee__last_name': 'حاجی ملا حیدر', 'resturaunt_day_meal__resturaunt_meal__name': 'چلو جوجه کباب زعفرانی'}
# --------------------------

# %%
currentdate = date.today()
results = Resturaunt_Employee_Day_Meal.objects.filter(resturaunt_day_meal__date__exact=currentdate).exclude(
        employee__department__company__name__exact='آسفالت طوس').exclude(employee__department__exact=None).values(
            'employee__department').order_by('employee__department__name').annotate(
        section=F('employee__department__name'), 
#         company_name=F('employee__department__company__name'),'company_name', 
        meal_name=F('resturaunt_day_meal__resturaunt_meal__name'), 
        meal_no=Count('resturaunt_day_meal__resturaunt_meal__name')).values('section', 'meal_name', 'meal_no')
for item in results:
    print(item) 
    print('-----------------------------------------')
# Out:
# {'section': 'آستو', 'company_name': 'آستو', 'meal_name': 'چلو جوجه کباب زعفرانی', 'meal_no': 18}
# -----------------------------------------
# {'section': 'آستو', 'company_name': 'آستو', 'meal_name': 'چلو خورش قورمه سبزی', 'meal_no': 6}
# -----------------------------------------
# {'section': 'آستو', 'company_name': 'آستو', 'meal_name': 'سالاد ماکارونی', 'meal_no': 2}
# -----------------------------------------
# {'section': 'آویژه صنعت', 'company_name': 'آویژه صنعت', 'meal_name': 'چلو جوجه کباب زعفرانی', 'meal_no': 36}
# -----------------------------------------
# {'section': 'آویژه صنعت', 'company_name': 'آویژه صنعت', 'meal_name': 'چلو خورش قورمه سبزی', 'meal_no': 8}
# -----------------------------------------
# {'section': 'آویژه صنعت', 'company_name': 'آویژه صنعت', 'meal_name': 'سالاد ماکارونی', 'meal_no': 3}
# -----------------------------------------
# {'section': 'آویژه صنعت', 'company_name': 'آویژه صنعت', 'meal_name': 'عدم انتخاب', 'meal_no': 2}
# -----------------------------------------
# {'section': 'بهاوند', 'company_name': 'بهاوند باراد', 'meal_name': 'چلو جوجه کباب زعفرانی', 'meal_no': 21}
# -----------------------------------------
# {'section': 'بهاوند', 'company_name': 'بهاوند باراد', 'meal_name': 'چلو خورش قورمه سبزی', 'meal_no': 4}
# -----------------------------------------
# {'section': 'بهاوند', 'company_name': 'بهاوند باراد', 'meal_name': 'سالاد ماکارونی', 'meal_no': 2}
# -----------------------------------------
# {'section': 'فلات پارس', 'company_name': 'فلات پارس', 'meal_name': 'چلو جوجه کباب زعفرانی', 'meal_no': 6}
# -----------------------------------------
# {'section': 'فلات پارس', 'company_name': 'فلات پارس', 'meal_name': 'چلو خورش قورمه سبزی', 'meal_no': 5}
# -----------------------------------------
# {'section': 'فلات پارس', 'company_name': 'فلات پارس', 'meal_name': 'عدم انتخاب', 'meal_no': 5}
# -----------------------------------------
# {'section': 'وریا طرح', 'company_name': 'وریا طرح', 'meal_name': 'چلو جوجه کباب زعفرانی', 'meal_no': 16}
# -----------------------------------------
# {'section': 'وریا طرح', 'company_name': 'وریا طرح', 'meal_name': 'چلو خورش قورمه سبزی', 'meal_no': 20}
# -----------------------------------------
# {'section': 'وریا طرح', 'company_name': 'وریا طرح', 'meal_name': 'سالاد ماکارونی', 'meal_no': 1}
# -----------------------------------------
# {'section': 'وریا طرح', 'company_name': 'وریا طرح', 'meal_name': 'عدم انتخاب', 'meal_no': 1}
# -----------------------------------------
# {'section': 'وریا طرح', 'company_name': 'وریا طرح', 'meal_name': 'عدم حضور', 'meal_no': 2}
# -----------------------------------------

# %%
import os
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

from ldap3 import Server, Connection, ALL, NTLM
LDAP_URL = 'dc.asft.co:389'
username = 'M.Aliakbar'
password = '1234567'
domain_user = 'asft\\' + username

server = Server(LDAP_URL, get_info=ALL)
conn = Connection(server, user=domain_user, password=password, authentication=NTLM, auto_bind=True)

base = '''dc=asft,dc=co'''
criteria = '''(objectCategory=user)'''
attributes = ['sAMAccountName', 'givenName', 'sn', 'mail', 'userAccountControl', 'thumbnailPhoto']

conn.search(base, criteria, attributes=attributes)
results = conn.response
print(len(results))
# Out:
# 512

# %%
date = '2021-09-05'
currentdate = datetime.strptime(date, '%Y-%m-%d').date()

y = currentdate.year
m = currentdate.month-1
d = currentdate.day
print(y)
print(m)
print(d)
startdate = ""
enddate = ""
if(m == 1):
    startdate += str(y) 
    startdate += "-01" if (d < 21) else "-02" 
    startdate += "-21" if (d < 21) else "-20"
    enddate += str(y) 
    enddate += "-02" if (d < 21) else "-03" 
    enddate += "-19" if (d < 21) else "-20"
elif(m == 2):
    startdate += str(y) 
    startdate += "-02" if (d < 20) else "-03" 
    startdate += "-20" if (d < 20) else "-21"
    enddate += str(y) 
    enddate += "-03" if (d < 20) else "-04" 
    enddate += "-20" if (d < 20) else "-20"
elif(m == 3):
    startdate += str(y) 
    startdate += "-03" if (d < 21) else "-04" 
    startdate += "-21" if (d < 21) else "-21"
    enddate += str(y) 
    enddate += "-04" if (d < 21) else "-05" 
    enddate += "-21" if (d < 21) else "-21"
elif(m == 4):
    startdate += str(y) 
    startdate += "-04" if (d < 21) else "-05" 
    startdate += "-21" if (d < 21) else "-22"
    enddate += str(y) 
    enddate += "-05" if (d < 21) else "-06" 
    enddate += "-21" if (d < 21) else "-21"            
elif(m == 5):
    startdate += str(y) 
    startdate += "-05" if (d < 22) else "-06" 
    startdate += "-22" if (d < 22) else "-22" 
    enddate += str(y) 
    enddate += "-06" if (d < 22) else "-07" 
    enddate += "-21" if (d < 22) else "-22"            
elif(m == 6):
    startdate += str(y) 
    startdate += "-06" if (d < 22) else "-07" 
    startdate += "-22" if (d < 22) else "-23" 
    enddate += str(y) 
    enddate += "-07" if (d < 22) else "-08" 
    enddate += "-22" if (d < 22) else "-22"            
elif(m == 7):
    startdate += str(y) 
    startdate += "-07" if (d < 23) else "-08" 
    startdate += "-23" if (d < 23) else "-23" 
    enddate += str(y) 
    enddate += "-08" if (d < 23) else "-09" 
    enddate += "-22" if (d < 23) else "-22"            
elif(m == 8):
    startdate += str(y) 
    startdate += "-08" if (d < 23) else "-09" 
    startdate += "-23" if (d < 23) else "-23" 
    enddate += str(y) 
    enddate += "-09" if (d < 21) else "-10" 
    enddate += "-22" if (d < 21) else "-22"
elif(m == 9):
    startdate = str(y) 
    startdate += "-09" if (d < 23) else "-10" 
    startdate += "-23" if (d < 23) else "-23" 
    enddate += str(y) 
    enddate += "-10" if (d < 21) else "-11" 
    enddate += "-22" if (d < 21) else "-21"            
elif(m == 10):
    startdate += str(y) 
    startdate += "-10" if (d < 23) else "-11" 
    startdate += "-23" if (d < 23) else "-22" 
    enddate += str(y) 
    enddate += "-11" if (d < 21) else "-12" 
    enddate += "-21" if (d < 21) else "-21"            
elif(m == 11):
    startdate += str(y) 
    startdate += "-11" if (d < 22) else "-12" 
    startdate += "-22" if (d < 22) else "-22" 
    enddate += str(y) 
    enddate += "-12" if (d < 21) else "-01" 
    enddate += "-21" if (d < 21) else "-20"
elif(m == 12):
    startdate += str(y) 
    startdate += "-12" if (d < 22) else "-01" 
    startdate += "-22" if (d < 22) else "-21"
    enddate += str(y) 
    enddate += "-01" if (d < 21) else "-02" 
    enddate += "-20" if (d < 21) else "-19"             
          

print(startdate)
print(enddate)
results = Resturaunt_Day_Meal.objects.filter(date__gte=startdate, date__lte=enddate).annotate(selectedNo=Count('ResturauntDayMeal_ResturauntEmployeeDayMeal'))
for item in results:
    print(item)
    print('-------------------------')
# Out:
# 2021
# 8
# 5
# 2021-08-23
# 2021-09-22
# Resturaunt_Day_Meal object (124)
# -------------------------
# Resturaunt_Day_Meal object (127)
# -------------------------
# Resturaunt_Day_Meal object (128)
# -------------------------
# Resturaunt_Day_Meal object (129)
# -------------------------
# Resturaunt_Day_Meal object (130)
# -------------------------
# Resturaunt_Day_Meal object (131)
# -------------------------
# Resturaunt_Day_Meal object (132)
# -------------------------
# Resturaunt_Day_Meal object (133)
# -------------------------
# Resturaunt_Day_Meal object (134)
# -------------------------
# Resturaunt_Day_Meal object (135)
# -------------------------
# Resturaunt_Day_Meal object (136)
# -------------------------
# Resturaunt_Day_Meal object (137)
# -------------------------
# Resturaunt_Day_Meal object (138)
# -------------------------
# Resturaunt_Day_Meal object (139)
# -------------------------
# Resturaunt_Day_Meal object (140)
# -------------------------
# Resturaunt_Day_Meal object (142)
# -------------------------
# Resturaunt_Day_Meal object (143)
# -------------------------
# Resturaunt_Day_Meal object (144)
# -------------------------
# Resturaunt_Day_Meal object (149)
# -------------------------
# Resturaunt_Day_Meal object (151)
# -------------------------
# Resturaunt_Day_Meal object (154)
# -------------------------
# Resturaunt_Day_Meal object (155)
# -------------------------
# Resturaunt_Day_Meal object (156)
# -------------------------
# Resturaunt_Day_Meal object (157)
# -------------------------
# Resturaunt_Day_Meal object (158)
# -------------------------
# Resturaunt_Day_Meal object (159)
# -------------------------
# Resturaunt_Day_Meal object (160)
# -------------------------
# Resturaunt_Day_Meal object (161)
# -------------------------
# Resturaunt_Day_Meal object (162)
# -------------------------
# Resturaunt_Day_Meal object (163)
# -------------------------
# Resturaunt_Day_Meal object (164)
# -------------------------
# Resturaunt_Day_Meal object (165)
# -------------------------
# Resturaunt_Day_Meal object (166)
# -------------------------
# Resturaunt_Day_Meal object (167)
# -------------------------
# Resturaunt_Day_Meal object (168)
# -------------------------
# Resturaunt_Day_Meal object (169)
# -------------------------
# Resturaunt_Day_Meal object (170)
# -------------------------
# Resturaunt_Day_Meal object (173)
# -------------------------
# Resturaunt_Day_Meal object (174)
# -------------------------
# Resturaunt_Day_Meal object (175)
# -------------------------
# Resturaunt_Day_Meal object (176)
# -------------------------
# Resturaunt_Day_Meal object (177)
# -------------------------
# Resturaunt_Day_Meal object (178)
# -------------------------
# Resturaunt_Day_Meal object (179)
# -------------------------
# Resturaunt_Day_Meal object (180)
# -------------------------
# Resturaunt_Day_Meal object (181)
# -------------------------
# Resturaunt_Day_Meal object (182)
# -------------------------
# Resturaunt_Day_Meal object (183)
# -------------------------
# Resturaunt_Day_Meal object (184)
# -------------------------
# Resturaunt_Day_Meal object (186)
# -------------------------
# Resturaunt_Day_Meal object (187)
# -------------------------
# Resturaunt_Day_Meal object (188)
# -------------------------
# Resturaunt_Day_Meal object (189)
# -------------------------
# Resturaunt_Day_Meal object (190)
# -------------------------
# Resturaunt_Day_Meal object (191)
# -------------------------
# Resturaunt_Day_Meal object (192)
# -------------------------
# Resturaunt_Day_Meal object (193)
# -------------------------
# Resturaunt_Day_Meal object (194)
# -------------------------
# Resturaunt_Day_Meal object (195)
# -------------------------
# Resturaunt_Day_Meal object (196)
# -------------------------
# Resturaunt_Day_Meal object (198)
# -------------------------
# Resturaunt_Day_Meal object (199)
# -------------------------
# Resturaunt_Day_Meal object (200)
# -------------------------
# Resturaunt_Day_Meal object (201)
# -------------------------
# Resturaunt_Day_Meal object (202)
# -------------------------
# Resturaunt_Day_Meal object (204)
# -------------------------
# Resturaunt_Day_Meal object (205)
# -------------------------
# Resturaunt_Day_Meal object (206)
# -------------------------
# Resturaunt_Day_Meal object (207)
# -------------------------
# Resturaunt_Day_Meal object (208)
# -------------------------
# Resturaunt_Day_Meal object (209)
# -------------------------
# Resturaunt_Day_Meal object (210)
# -------------------------
# Resturaunt_Day_Meal object (211)
# -------------------------
# Resturaunt_Day_Meal object (213)
# -------------------------
# Resturaunt_Day_Meal object (214)
# -------------------------
# Resturaunt_Day_Meal object (215)
# -------------------------
# Resturaunt_Day_Meal object (216)
# -------------------------
# Resturaunt_Day_Meal object (217)
# -------------------------
# Resturaunt_Day_Meal object (218)
# -------------------------
# Resturaunt_Day_Meal object (219)
# -------------------------
# Resturaunt_Day_Meal object (220)
# -------------------------
# Resturaunt_Day_Meal object (221)
# -------------------------
# Resturaunt_Day_Meal object (222)
# -------------------------
# Resturaunt_Day_Meal object (223)
# -------------------------
# Resturaunt_Day_Meal object (224)
# -------------------------
# Resturaunt_Day_Meal object (225)
# -------------------------
# Resturaunt_Day_Meal object (226)
# -------------------------
# Resturaunt_Day_Meal object (227)
# -------------------------
# Resturaunt_Day_Meal object (228)
# -------------------------
# Resturaunt_Day_Meal object (229)
# -------------------------
# Resturaunt_Day_Meal object (230)
# -------------------------
# Resturaunt_Day_Meal object (231)
# -------------------------
# Resturaunt_Day_Meal object (232)
# -------------------------
# Resturaunt_Day_Meal object (233)
# -------------------------
# Resturaunt_Day_Meal object (234)
# -------------------------
# Resturaunt_Day_Meal object (235)
# -------------------------
# Resturaunt_Day_Meal object (236)
# -------------------------
# Resturaunt_Day_Meal object (237)
# -------------------------
# Resturaunt_Day_Meal object (238)
# -------------------------
# Resturaunt_Day_Meal object (239)
# -------------------------
# Resturaunt_Day_Meal object (240)
# -------------------------
# Resturaunt_Day_Meal object (241)
# -------------------------
# Resturaunt_Day_Meal object (242)
# -------------------------
# Resturaunt_Day_Meal object (243)
# -------------------------
# Resturaunt_Day_Meal object (244)
# -------------------------
# Resturaunt_Day_Meal object (245)
# -------------------------
# Resturaunt_Day_Meal object (246)
# -------------------------
# Resturaunt_Day_Meal object (247)
# -------------------------
# Resturaunt_Day_Meal object (248)
# -------------------------
# Resturaunt_Day_Meal object (249)
# -------------------------
# Resturaunt_Day_Meal object (250)
# -------------------------
# Resturaunt_Day_Meal object (251)
# -------------------------
# Resturaunt_Day_Meal object (252)
# -------------------------
# Resturaunt_Day_Meal object (253)
# -------------------------
# Resturaunt_Day_Meal object (254)
# -------------------------
# Resturaunt_Day_Meal object (255)
# -------------------------

# %%
from datetime import date

currentdate = date.today()
projectId = 5
# date = datetime.strptime(currentdate, '%Y-%m-%d').date()   'employee__first_name', 

result1 = Resturaunt_Day_Meal.objects.filter(date__exact=currentdate)
for item in result1:
    print(item)
    print('--------------------')
result = Resturaunt_Employee_Day_Meal.objects.filter(resturaunt_day_meal__in=result1, employee__project_id__exact=projectId).values(
                    'id', 'employee__last_name', 'resturaunt_day_meal', 'resturaunt_day_meal__resturaunt_meal__name')
for item in result:
    print(item)
    print('---------------------------------')
results = Resturaunt_Employee_Day_Meal.objects.filter(employee__exact=1682).values('employee', 'resturaunt_day_meal')
for item in results:
    print(item)
    print('---------------')
# Out:
# Resturaunt_Day_Meal object (167)
# --------------------
# Resturaunt_Day_Meal object (168)
# --------------------
# Resturaunt_Day_Meal object (169)
# --------------------
# Resturaunt_Day_Meal object (220)
# --------------------
# Resturaunt_Day_Meal object (243)
# --------------------
# {'id': 7028, 'employee__last_name': 'توحیدی', 'resturaunt_day_meal': 169, 'resturaunt_day_meal__resturaunt_meal__name': 'خوراک فیله مرغ با سبزیجات'}
# ---------------------------------
# {'id': 5970, 'employee__last_name': 'کریمی', 'resturaunt_day_meal': 169, 'resturaunt_day_meal__resturaunt_meal__name': 'خوراک فیله مرغ با سبزیجات'}
# ---------------------------------
# {'id': 5122, 'employee__last_name': 'بهرامزادگان', 'resturaunt_day_meal': 169, 'resturaunt_day_meal__resturaunt_meal__name': 'خوراک فیله مرغ با سبزیجات'}
# ---------------------------------
# {'id': 5294, 'employee__last_name': 'باسخا', 'resturaunt_day_meal': 167, 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش آلو اسفناج'}
# ---------------------------------
# {'id': 5023, 'employee__last_name': 'شکفته', 'resturaunt_day_meal': 167, 'resturaunt_day_meal__resturaunt_meal__name': 'چلو خورش آلو اسفناج'}
# ---------------------------------
# {'employee': 1682, 'resturaunt_day_meal': 189}
# ---------------
# {'employee': 1682, 'resturaunt_day_meal': 192}
# ---------------
# {'employee': 1682, 'resturaunt_day_meal': 195}
# ---------------
# {'employee': 1682, 'resturaunt_day_meal': 174}
# ---------------
# {'employee': 1682, 'resturaunt_day_meal': 178}
# ---------------
# {'employee': 1682, 'resturaunt_day_meal': 181}
# ---------------
# {'employee': 1682, 'resturaunt_day_meal': 183}
# ---------------
# {'employee': 1682, 'resturaunt_day_meal': 188}
# ---------------
# {'employee': 1682, 'resturaunt_day_meal': 200}
# ---------------
# {'employee': 1682, 'resturaunt_day_meal': 202}
# ---------------

# %%
currentdate = date.today()
y = currentdate.year
m = currentdate.month-1
d = currentdate.day
startdate = ""
enddate = ""
if(m == 1):
    startdate += str(y) 
    startdate += "-01" if (d < 21) else "-02" 
    startdate += "-21" if (d < 21) else "-20"
    enddate += str(y) 
    enddate += "-02" if (d < 21) else "-03" 
    enddate += "-19" if (d < 21) else "-20"
elif(m == 2):
    startdate += str(y) 
    startdate += "-02" if (d < 20) else "-03" 
    startdate += "-20" if (d < 20) else "-21"
    enddate += str(y) 
    enddate += "-03" if (d < 20) else "-04" 
    enddate += "-20" if (d < 20) else "-20"
elif(m == 3):
    startdate += str(y) 
    startdate += "-03" if (d < 21) else "-04" 
    startdate += "-21" if (d < 21) else "-21"
    enddate += str(y) 
    enddate += "-04" if (d < 21) else "-05" 
    enddate += "-21" if (d < 21) else "-21"
elif(m == 4):
    startdate += str(y) 
    startdate += "-04" if (d < 21) else "-05" 
    startdate += "-21" if (d < 21) else "-22"
    enddate += str(y) 
    enddate += "-05" if (d < 21) else "-06" 
    enddate += "-21" if (d < 21) else "-21"            
elif(m == 5):
    startdate += str(y) 
    startdate += "-05" if (d < 22) else "-06" 
    startdate += "-22" if (d < 22) else "-22" 
    enddate += str(y) 
    enddate += "-06" if (d < 22) else "-07" 
    enddate += "-21" if (d < 22) else "-22"            
elif(m == 6):
    startdate += str(y) 
    startdate += "-06" if (d < 22) else "-07" 
    startdate += "-22" if (d < 22) else "-23" 
    enddate += str(y) 
    enddate += "-07" if (d < 22) else "-08" 
    enddate += "-22" if (d < 22) else "-22"            
elif(m == 7):
    startdate += str(y) 
    startdate += "-07" if (d < 23) else "-08" 
    startdate += "-23" if (d < 23) else "-23" 
    enddate += str(y) 
    enddate += "-08" if (d < 23) else "-09" 
    enddate += "-22" if (d < 23) else "-22"            
elif(m == 8):
    startdate += str(y) 
    startdate += "-08" if (d < 23) else "-09" 
    startdate += "-23" if (d < 23) else "-23" 
    enddate += str(y) 
    enddate += "-09" if (d < 21) else "-10" 
    enddate += "-22" if (d < 21) else "-22"
elif(m == 9):
    startdate = str(y) 
    startdate += "-09" if (d < 23) else "-10" 
    startdate += "-23" if (d < 23) else "-23" 
    enddate += str(y) 
    enddate += "-10" if (d < 21) else "-11" 
    enddate += "-22" if (d < 21) else "-21"            
elif(m == 10):
    startdate += str(y) 
    startdate += "-10" if (d < 23) else "-11" 
    startdate += "-23" if (d < 23) else "-22" 
    enddate += str(y) 
    enddate += "-11" if (d < 21) else "-12" 
    enddate += "-21" if (d < 21) else "-21"            
elif(m == 11):
    startdate += str(y) 
    startdate += "-11" if (d < 22) else "-12" 
    startdate += "-22" if (d < 22) else "-22" 
    enddate += str(y) 
    enddate += "-12" if (d < 21) else "-01" 
    enddate += "-21" if (d < 21) else "-20"
elif(m == 12):
    startdate += str(y) 
    startdate += "-12" if (d < 22) else "-01" 
    startdate += "-22" if (d < 22) else "-21"
    enddate += str(y) 
    enddate += "-01" if (d < 21) else "-02" 
    enddate += "-20" if (d < 21) else "-19"             
    
# .select_related('ResturauntDayMeal_ResturauntEmployeeDayMeal')

results = Resturaunt_Day_Meal.objects.filter(date__gte=startdate, date__lte=enddate).annotate(
    selectedNo=Count('ResturauntDayMeal_ResturauntEmployeeDayMeal')).values(
    'id', 'date', 'totalNo', 'resturaunt_meal', 'selectedNo')

for item in results:
    print(item)
    print('------------------------------')
# Out:
# {'id': 124, 'date': datetime.date(2021, 8, 23), 'totalNo': 0, 'resturaunt_meal': 54, 'selectedNo': 265}
# ------------------------------
# {'id': 127, 'date': datetime.date(2021, 8, 23), 'totalNo': 0, 'resturaunt_meal': 34, 'selectedNo': 76}
# ------------------------------
# {'id': 128, 'date': datetime.date(2021, 8, 23), 'totalNo': 0, 'resturaunt_meal': 3, 'selectedNo': 9}
# ------------------------------
# {'id': 129, 'date': datetime.date(2021, 8, 24), 'totalNo': 0, 'resturaunt_meal': 1, 'selectedNo': 158}
# ------------------------------
# {'id': 130, 'date': datetime.date(2021, 8, 24), 'totalNo': 0, 'resturaunt_meal': 21, 'selectedNo': 78}
# ------------------------------
# {'id': 131, 'date': datetime.date(2021, 8, 24), 'totalNo': 0, 'resturaunt_meal': 13, 'selectedNo': 114}
# ------------------------------
# {'id': 132, 'date': datetime.date(2021, 8, 25), 'totalNo': 0, 'resturaunt_meal': 31, 'selectedNo': 262}
# ------------------------------
# {'id': 133, 'date': datetime.date(2021, 8, 25), 'totalNo': 0, 'resturaunt_meal': 10, 'selectedNo': 28}
# ------------------------------
# {'id': 134, 'date': datetime.date(2021, 8, 25), 'totalNo': 0, 'resturaunt_meal': 57, 'selectedNo': 57}
# ------------------------------
# {'id': 135, 'date': datetime.date(2021, 8, 28), 'totalNo': 0, 'resturaunt_meal': 56, 'selectedNo': 216}
# ------------------------------
# {'id': 136, 'date': datetime.date(2021, 8, 28), 'totalNo': 0, 'resturaunt_meal': 9, 'selectedNo': 115}
# ------------------------------
# {'id': 137, 'date': datetime.date(2021, 8, 28), 'totalNo': 0, 'resturaunt_meal': 16, 'selectedNo': 17}
# ------------------------------
# {'id': 138, 'date': datetime.date(2021, 8, 29), 'totalNo': 0, 'resturaunt_meal': 28, 'selectedNo': 175}
# ------------------------------
# {'id': 139, 'date': datetime.date(2021, 8, 29), 'totalNo': 0, 'resturaunt_meal': 30, 'selectedNo': 123}
# ------------------------------
# {'id': 140, 'date': datetime.date(2021, 8, 29), 'totalNo': 0, 'resturaunt_meal': 25, 'selectedNo': 50}
# ------------------------------
# {'id': 142, 'date': datetime.date(2021, 8, 30), 'totalNo': 0, 'resturaunt_meal': 32, 'selectedNo': 253}
# ------------------------------
# {'id': 143, 'date': datetime.date(2021, 8, 30), 'totalNo': 0, 'resturaunt_meal': 21, 'selectedNo': 45}
# ------------------------------
# {'id': 144, 'date': datetime.date(2021, 8, 30), 'totalNo': 0, 'resturaunt_meal': 41, 'selectedNo': 52}
# ------------------------------
# {'id': 149, 'date': datetime.date(2021, 8, 31), 'totalNo': 0, 'resturaunt_meal': 34, 'selectedNo': 183}
# ------------------------------
# {'id': 151, 'date': datetime.date(2021, 9, 1), 'totalNo': 0, 'resturaunt_meal': 58, 'selectedNo': 159}
# ------------------------------
# {'id': 154, 'date': datetime.date(2021, 9, 1), 'totalNo': 0, 'resturaunt_meal': 10, 'selectedNo': 25}
# ------------------------------
# {'id': 155, 'date': datetime.date(2021, 9, 1), 'totalNo': 0, 'resturaunt_meal': 52, 'selectedNo': 166}
# ------------------------------
# {'id': 156, 'date': datetime.date(2021, 8, 31), 'totalNo': 0, 'resturaunt_meal': 50, 'selectedNo': 78}
# ------------------------------
# {'id': 157, 'date': datetime.date(2021, 8, 31), 'totalNo': 0, 'resturaunt_meal': 48, 'selectedNo': 87}
# ------------------------------
# {'id': 158, 'date': datetime.date(2021, 9, 4), 'totalNo': 0, 'resturaunt_meal': 1, 'selectedNo': 90}
# ------------------------------
# {'id': 159, 'date': datetime.date(2021, 9, 4), 'totalNo': 0, 'resturaunt_meal': 4, 'selectedNo': 237}
# ------------------------------
# {'id': 160, 'date': datetime.date(2021, 9, 4), 'totalNo': 0, 'resturaunt_meal': 17, 'selectedNo': 20}
# ------------------------------
# {'id': 161, 'date': datetime.date(2021, 9, 5), 'totalNo': 0, 'resturaunt_meal': 14, 'selectedNo': 173}
# ------------------------------
# {'id': 162, 'date': datetime.date(2021, 9, 5), 'totalNo': 0, 'resturaunt_meal': 51, 'selectedNo': 105}
# ------------------------------
# {'id': 163, 'date': datetime.date(2021, 9, 5), 'totalNo': 0, 'resturaunt_meal': 24, 'selectedNo': 58}
# ------------------------------
# {'id': 164, 'date': datetime.date(2021, 9, 6), 'totalNo': 0, 'resturaunt_meal': 54, 'selectedNo': 232}
# ------------------------------
# {'id': 165, 'date': datetime.date(2021, 9, 6), 'totalNo': 0, 'resturaunt_meal': 33, 'selectedNo': 68}
# ------------------------------
# {'id': 166, 'date': datetime.date(2021, 9, 6), 'totalNo': 0, 'resturaunt_meal': 44, 'selectedNo': 38}
# ------------------------------
# {'id': 167, 'date': datetime.date(2021, 9, 7), 'totalNo': 0, 'resturaunt_meal': 23, 'selectedNo': 76}
# ------------------------------
# {'id': 168, 'date': datetime.date(2021, 9, 7), 'totalNo': 0, 'resturaunt_meal': 15, 'selectedNo': 83}
# ------------------------------
# {'id': 169, 'date': datetime.date(2021, 9, 7), 'totalNo': 0, 'resturaunt_meal': 47, 'selectedNo': 172}
# ------------------------------
# {'id': 170, 'date': datetime.date(2021, 9, 8), 'totalNo': 0, 'resturaunt_meal': 59, 'selectedNo': 228}
# ------------------------------
# {'id': 173, 'date': datetime.date(2021, 9, 11), 'totalNo': 0, 'resturaunt_meal': 9, 'selectedNo': 137}
# ------------------------------
# {'id': 174, 'date': datetime.date(2021, 9, 11), 'totalNo': 0, 'resturaunt_meal': 4, 'selectedNo': 195}
# ------------------------------
# {'id': 175, 'date': datetime.date(2021, 9, 11), 'totalNo': 0, 'resturaunt_meal': 18, 'selectedNo': 44}
# ------------------------------
# {'id': 176, 'date': datetime.date(2021, 9, 12), 'totalNo': 0, 'resturaunt_meal': 56, 'selectedNo': 147}
# ------------------------------
# {'id': 177, 'date': datetime.date(2021, 9, 12), 'totalNo': 0, 'resturaunt_meal': 21, 'selectedNo': 100}
# ------------------------------
# {'id': 178, 'date': datetime.date(2021, 9, 12), 'totalNo': 0, 'resturaunt_meal': 26, 'selectedNo': 121}
# ------------------------------
# {'id': 179, 'date': datetime.date(2021, 9, 13), 'totalNo': 0, 'resturaunt_meal': 33, 'selectedNo': 71}
# ------------------------------
# {'id': 180, 'date': datetime.date(2021, 9, 13), 'totalNo': 0, 'resturaunt_meal': 58, 'selectedNo': 68}
# ------------------------------
# {'id': 181, 'date': datetime.date(2021, 9, 13), 'totalNo': 0, 'resturaunt_meal': 20, 'selectedNo': 233}
# ------------------------------
# {'id': 182, 'date': datetime.date(2021, 9, 14), 'totalNo': 0, 'resturaunt_meal': 15, 'selectedNo': 187}
# ------------------------------
# {'id': 183, 'date': datetime.date(2021, 9, 14), 'totalNo': 0, 'resturaunt_meal': 10, 'selectedNo': 100}
# ------------------------------
# {'id': 184, 'date': datetime.date(2021, 9, 14), 'totalNo': 0, 'resturaunt_meal': 3, 'selectedNo': 79}
# ------------------------------
# {'id': 186, 'date': datetime.date(2021, 9, 15), 'totalNo': 0, 'resturaunt_meal': 1, 'selectedNo': 137}
# ------------------------------
# {'id': 187, 'date': datetime.date(2021, 9, 15), 'totalNo': 0, 'resturaunt_meal': 30, 'selectedNo': 62}
# ------------------------------
# {'id': 188, 'date': datetime.date(2021, 9, 15), 'totalNo': 0, 'resturaunt_meal': 49, 'selectedNo': 171}
# ------------------------------
# {'id': 189, 'date': datetime.date(2021, 9, 18), 'totalNo': 0, 'resturaunt_meal': 4, 'selectedNo': 197}
# ------------------------------
# {'id': 190, 'date': datetime.date(2021, 9, 18), 'totalNo': 0, 'resturaunt_meal': 51, 'selectedNo': 47}
# ------------------------------
# {'id': 191, 'date': datetime.date(2021, 9, 18), 'totalNo': 0, 'resturaunt_meal': 60, 'selectedNo': 129}
# ------------------------------
# {'id': 192, 'date': datetime.date(2021, 9, 19), 'totalNo': 0, 'resturaunt_meal': 21, 'selectedNo': 217}
# ------------------------------
# {'id': 193, 'date': datetime.date(2021, 9, 19), 'totalNo': 0, 'resturaunt_meal': 50, 'selectedNo': 90}
# ------------------------------
# {'id': 194, 'date': datetime.date(2021, 9, 19), 'totalNo': 0, 'resturaunt_meal': 16, 'selectedNo': 61}
# ------------------------------
# {'id': 195, 'date': datetime.date(2021, 9, 20), 'totalNo': 0, 'resturaunt_meal': 59, 'selectedNo': 240}
# ------------------------------
# {'id': 196, 'date': datetime.date(2021, 9, 20), 'totalNo': 0, 'resturaunt_meal': 22, 'selectedNo': 94}
# ------------------------------
# {'id': 198, 'date': datetime.date(2021, 9, 21), 'totalNo': 0, 'resturaunt_meal': 1, 'selectedNo': 100}
# ------------------------------
# {'id': 199, 'date': datetime.date(2021, 9, 21), 'totalNo': 0, 'resturaunt_meal': 27, 'selectedNo': 98}
# ------------------------------
# {'id': 200, 'date': datetime.date(2021, 9, 21), 'totalNo': 0, 'resturaunt_meal': 13, 'selectedNo': 170}
# ------------------------------
# {'id': 201, 'date': datetime.date(2021, 9, 22), 'totalNo': 0, 'resturaunt_meal': 58, 'selectedNo': 200}
# ------------------------------
# {'id': 202, 'date': datetime.date(2021, 9, 22), 'totalNo': 0, 'resturaunt_meal': 30, 'selectedNo': 130}
# ------------------------------
# {'id': 204, 'date': datetime.date(2021, 9, 8), 'totalNo': 0, 'resturaunt_meal': 10, 'selectedNo': 38}
# ------------------------------
# {'id': 205, 'date': datetime.date(2021, 9, 8), 'totalNo': 0, 'resturaunt_meal': 41, 'selectedNo': 70}
# ------------------------------
# {'id': 206, 'date': datetime.date(2021, 9, 22), 'totalNo': 0, 'resturaunt_meal': 36, 'selectedNo': 37}
# ------------------------------
# {'id': 207, 'date': datetime.date(2021, 9, 20), 'totalNo': 0, 'resturaunt_meal': 19, 'selectedNo': 38}
# ------------------------------
# {'id': 208, 'date': datetime.date(2021, 8, 23), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 6}
# ------------------------------
# {'id': 209, 'date': datetime.date(2021, 8, 24), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 6}
# ------------------------------
# {'id': 210, 'date': datetime.date(2021, 8, 25), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 8}
# ------------------------------
# {'id': 211, 'date': datetime.date(2021, 8, 28), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 8}
# ------------------------------
# {'id': 213, 'date': datetime.date(2021, 8, 29), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 8}
# ------------------------------
# {'id': 214, 'date': datetime.date(2021, 8, 30), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 6}
# ------------------------------
# {'id': 215, 'date': datetime.date(2021, 8, 31), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 8}
# ------------------------------
# {'id': 216, 'date': datetime.date(2021, 9, 1), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 6}
# ------------------------------
# {'id': 217, 'date': datetime.date(2021, 9, 4), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 9}
# ------------------------------
# {'id': 218, 'date': datetime.date(2021, 9, 5), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 12}
# ------------------------------
# {'id': 219, 'date': datetime.date(2021, 9, 6), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 8}
# ------------------------------
# {'id': 220, 'date': datetime.date(2021, 9, 7), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 13}
# ------------------------------
# {'id': 221, 'date': datetime.date(2021, 9, 8), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 13}
# ------------------------------
# {'id': 222, 'date': datetime.date(2021, 9, 11), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 11}
# ------------------------------
# {'id': 223, 'date': datetime.date(2021, 9, 12), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 11}
# ------------------------------
# {'id': 224, 'date': datetime.date(2021, 9, 13), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 8}
# ------------------------------
# {'id': 225, 'date': datetime.date(2021, 9, 14), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 16}
# ------------------------------
# {'id': 226, 'date': datetime.date(2021, 9, 15), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 13}
# ------------------------------
# {'id': 227, 'date': datetime.date(2021, 9, 18), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 11}
# ------------------------------
# {'id': 228, 'date': datetime.date(2021, 9, 19), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 13}
# ------------------------------
# {'id': 229, 'date': datetime.date(2021, 9, 20), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 11}
# ------------------------------
# {'id': 230, 'date': datetime.date(2021, 9, 21), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 13}
# ------------------------------
# {'id': 231, 'date': datetime.date(2021, 9, 22), 'totalNo': 0, 'resturaunt_meal': 61, 'selectedNo': 13}
# ------------------------------
# {'id': 232, 'date': datetime.date(2021, 8, 23), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 0}
# ------------------------------
# {'id': 233, 'date': datetime.date(2021, 8, 24), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 0}
# ------------------------------
# {'id': 234, 'date': datetime.date(2021, 8, 25), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 1}
# ------------------------------
# {'id': 235, 'date': datetime.date(2021, 8, 28), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 0}
# ------------------------------
# {'id': 236, 'date': datetime.date(2021, 8, 29), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 0}
# ------------------------------
# {'id': 237, 'date': datetime.date(2021, 8, 30), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 0}
# ------------------------------
# {'id': 238, 'date': datetime.date(2021, 8, 31), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 0}
# ------------------------------
# {'id': 239, 'date': datetime.date(2021, 9, 1), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 0}
# ------------------------------
# {'id': 240, 'date': datetime.date(2021, 9, 4), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 3}
# ------------------------------
# {'id': 241, 'date': datetime.date(2021, 9, 5), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 9}
# ------------------------------
# {'id': 242, 'date': datetime.date(2021, 9, 6), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 10}
# ------------------------------
# {'id': 243, 'date': datetime.date(2021, 9, 7), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 12}
# ------------------------------
# {'id': 244, 'date': datetime.date(2021, 9, 8), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 12}
# ------------------------------
# {'id': 245, 'date': datetime.date(2021, 9, 11), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 12}
# ------------------------------
# {'id': 246, 'date': datetime.date(2021, 9, 12), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 14}
# ------------------------------
# {'id': 247, 'date': datetime.date(2021, 9, 13), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 13}
# ------------------------------
# {'id': 248, 'date': datetime.date(2021, 9, 14), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 12}
# ------------------------------
# {'id': 249, 'date': datetime.date(2021, 9, 15), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 11}
# ------------------------------
# {'id': 250, 'date': datetime.date(2021, 9, 18), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 9}
# ------------------------------
# {'id': 251, 'date': datetime.date(2021, 9, 19), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 12}
# ------------------------------
# {'id': 252, 'date': datetime.date(2021, 9, 20), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 10}
# ------------------------------
# {'id': 253, 'date': datetime.date(2021, 9, 21), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 12}
# ------------------------------
# {'id': 254, 'date': datetime.date(2021, 9, 22), 'totalNo': 0, 'resturaunt_meal': 62, 'selectedNo': 13}
# ------------------------------
# {'id': 255, 'date': datetime.date(2021, 8, 23), 'totalNo': 0, 'resturaunt_meal': 2, 'selectedNo': 0}
# ------------------------------
